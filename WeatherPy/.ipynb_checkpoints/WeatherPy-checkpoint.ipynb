# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import scipy.stats as st

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 616

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
print ('Beginning Data Retrieval')
print ('-----------------------------')

# Create empty lists of our variables
cityList = []
cloudinessList = []
countryList = [] 
dateList = []
humidityList = []
latList = [] 
lngList = [] 
maxTempList = [] 
windSpeedList = []
indexCounter = 0
setCounter = 1

base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = 'imperial'
query_url = f"{base_url}appid={weather_api_key}&units={units}&q="

# For loop through the cities list, for each city in city list 
for index, city in enumerate(cities, start = 1):
    try:
        response = requests.get(query_url + city).json()
        cityList.append(response["name"])
        cloudinessList.append(response['clouds']['all'])
        countryList.append(response["sys"]["country"])
        dateList.append(response["dt"])
        humidityList.append(response["main"]["humidity"])
        latList.append(response["coord"]["lat"])
        lngList.append(response["coord"]["lon"])
        maxTempList.append(response['main']['temp_max'])
        windSpeedList.append(response["wind"]["speed"])
        if indexCounter > 49:
            indexCounter = 0
            setCounter += 1
    
        else:
            indexCounter += 1
            
        print(f"Processing Record {indexCounter} of Set {setCounter} | {city}") 
  
    except(KeyError, IndexError):
        print("City not found. Skipping...")

print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | arraial do cabo
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | tasiilaq
# Processing Record 4 of Set 1 | half moon bay
# Processing Record 5 of Set 1 | montefiascone
# Processing Record 6 of Set 1 | egvekinot
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | cabo san lucas
# Processing Record 9 of Set 1 | ust-omchug
# Processing Record 10 of Set 1 | kapaa
# Processing Record 11 of Set 1 | saint george
# City not found. Skipping...
# Processing Record 12 of Set 1 | port blair
# Processing Record 13 of Set 1 | yuci
# Processing Record 14 of Set 1 | mahebourg
# Processing Record 15 of Set 1 | vaini
# Processing Record 16 of Set 1 | port elizabeth
# Processing Record 17 of Set 1 | clyde river
# Processing Record 18 of Set 1 | gbarnga
# Processing Record 19 of Set 1 | jamestown
# Processing Record 20 of Set 1 | aklavik
# Processing Record 21 of Set 1 | mar del plata
# Processing Record 22 of Set 1 | ola
# Processing Record 23 of Set 1 | namibe
# Processing Record 24 of Set 1 | leh
# Processing Record 25 of Set 1 | atuona
# Processing Record 26 of Set 1 | tuktoyaktuk
# Processing Record 27 of Set 1 | cape town
# Processing Record 28 of Set 1 | haines junction
# Processing Record 29 of Set 1 | narsaq
# Processing Record 30 of Set 1 | bredasdorp
# Processing Record 31 of Set 1 | new norfolk
# Processing Record 32 of Set 1 | bend
# City not found. Skipping...
# Processing Record 33 of Set 1 | lebu
# Processing Record 34 of Set 1 | pevek
# Processing Record 35 of Set 1 | baiyin
# Processing Record 36 of Set 1 | leningradskiy
# Processing Record 37 of Set 1 | tiksi
# Processing Record 38 of Set 1 | gazojak
# Processing Record 39 of Set 1 | thinadhoo
# Processing Record 40 of Set 1 | price
# Processing Record 41 of Set 1 | albany
# Processing Record 42 of Set 1 | luderitz
# Processing Record 43 of Set 1 | sarakhs
# Processing Record 44 of Set 1 | thompson
# City not found. Skipping...
# Processing Record 45 of Set 1 | chokurdakh
# Processing Record 46 of Set 1 | port alfred
# Processing Record 47 of Set 1 | punta arenas
# Processing Record 48 of Set 1 | barrow
# City not found. Skipping...
# Processing Record 49 of Set 1 | souillac
# Processing Record 50 of Set 1 | yellowknife
# Processing Record 0 of Set 2 | winnemucca
# Processing Record 1 of Set 2 | port keats
# Processing Record 2 of Set 2 | bluff
# Processing Record 3 of Set 2 | avarua
# Processing Record 47 of Set 4 | buala
# Processing Record 48 of Set 4 | shingu
# Processing Record 49 of Set 4 | barra dos coqueiros
# Processing Record 50 of Set 4 | pinotepa nacional
# Processing Record 0 of Set 5 | the valley
# City not found. Skipping...
# Processing Record 1 of Set 5 | cayenne
# Processing Record 2 of Set 5 | baherden
# Processing Record 3 of Set 5 | jinxiang
# City not found. Skipping...
# Processing Record 4 of Set 5 | victoria
# Processing Record 5 of Set 5 | lagoa
# Processing Record 6 of Set 5 | boa vista
# Processing Record 7 of Set 5 | tilichiki
# Processing Record 8 of Set 5 | hobyo
# Processing Record 9 of Set 5 | nouadhibou
# Processing Record 10 of Set 5 | lazaro cardenas
# Processing Record 11 of Set 5 | faanui
# Processing Record 12 of Set 5 | lulea
# Processing Record 13 of Set 5 | suamico
# Processing Record 14 of Set 5 | zanjan
# Processing Record 15 of Set 5 | makurdi
# Processing Record 16 of Set 5 | dingle
# Processing Record 17 of Set 5 | baykit
# Processing Record 18 of Set 5 | lobito
# Processing Record 19 of Set 5 | opuwo
# Processing Record 20 of Set 5 | pokhara
# Processing Record 21 of Set 5 | tuatapere
# Processing Record 22 of Set 5 | pushkino
# Processing Record 23 of Set 5 | severo-kurilsk
# City not found. Skipping...
# Processing Record 24 of Set 5 | tabas
# Processing Record 25 of Set 5 | ponta do sol
# Processing Record 26 of Set 5 | bombay
# Processing Record 27 of Set 5 | bara
# City not found. Skipping...
# Processing Record 28 of Set 5 | luwuk
# Processing Record 29 of Set 5 | san patricio
# Processing Record 30 of Set 5 | tessalit
# City not found. Skipping...
# Processing Record 31 of Set 5 | ballina
# Processing Record 32 of Set 5 | college
# Processing Record 33 of Set 5 | saint-georges
# Processing Record 34 of Set 5 | meghraj
# Processing Record 35 of Set 5 | pushkinskiye gory
# City not found. Skipping...
# Processing Record 36 of Set 5 | general nakar
# Processing Record 37 of Set 5 | roseburg
# Processing Record 38 of Set 5 | bushenyi
# Processing Record 39 of Set 5 | prieska
# Processing Record 40 of Set 5 | ketchikan
# City not found. Skipping...
# Processing Record 41 of Set 5 | necochea
# Processing Record 42 of Set 5 | fukue
# Processing Record 43 of Set 5 | east london
# Processing Record 44 of Set 5 | ahipara
# Processing Record 45 of Set 5 | arrecife
# Processing Record 46 of Set 5 | nanortalik
# Processing Record 47 of Set 5 | platanos
# Processing Record 48 of Set 5 | kholodnyy
# Processing Record 49 of Set 5 | hay river
# Processing Record 50 of Set 5 | rurrenabaque
# Processing Record 0 of Set 6 | svetlyy
# Processing Record 1 of Set 6 | lagos
# Processing Record 2 of Set 6 | canita
# City not found. Skipping...
# Processing Record 3 of Set 6 | cortes
# Processing Record 4 of Set 6 | davila
# Processing Record 5 of Set 6 | lexington park
# Processing Record 6 of Set 6 | kaitangata
# Processing Record 7 of Set 6 | billings
# Processing Record 8 of Set 6 | dunedin
# Processing Record 9 of Set 6 | kununurra
# Processing Record 10 of Set 6 | strai
# Processing Record 11 of Set 6 | grand gaube
# Processing Record 12 of Set 6 | petropavlovka
# Processing Record 13 of Set 6 | teya
# Processing Record 14 of Set 6 | emba
# Processing Record 15 of Set 6 | le vauclin
# Processing Record 16 of Set 6 | saint anthony
# Processing Record 17 of Set 6 | shimoda
# Processing Record 18 of Set 6 | atambua
# Processing Record 19 of Set 6 | ashqelon
# Processing Record 20 of Set 6 | fallon
# Processing Record 21 of Set 6 | kadoma
# Processing Record 22 of Set 6 | elko
# Processing Record 23 of Set 6 | saryg-sep
# Processing Record 24 of Set 6 | maldonado
# Processing Record 25 of Set 6 | gizo
# Processing Record 26 of Set 6 | anadyr
# Processing Record 27 of Set 6 | talnakh
# Processing Record 28 of Set 6 | karachi
# Processing Record 29 of Set 6 | palmas bellas
# Processing Record 30 of Set 6 | ancud
# Processing Record 31 of Set 6 | jashpurnagar
# Processing Record 32 of Set 6 | ochamchira
# Processing Record 33 of Set 6 | ust-maya
# Processing Record 34 of Set 6 | deep river
# Processing Record 35 of Set 6 | liku
# City not found. Skipping...
# Processing Record 36 of Set 6 | yumen
# Processing Record 37 of Set 6 | severo-yeniseyskiy
# Processing Record 38 of Set 6 | noumea
# Processing Record 39 of Set 6 | dzilam gonzalez
# Processing Record 40 of Set 6 | raga
# Processing Record 41 of Set 6 | tublay
# Processing Record 42 of Set 6 | labuhan
# Processing Record 43 of Set 6 | palmer
# Processing Record 44 of Set 6 | bubaque
# Processing Record 45 of Set 6 | shalinskoye
# Processing Record 46 of Set 6 | katobu
# Processing Record 47 of Set 6 | popondetta
# Processing Record 48 of Set 6 | umm lajj
# Processing Record 49 of Set 6 | urumqi
# Processing Record 50 of Set 6 | bagdarin
# Processing Record 0 of Set 7 | makakilo city
# Processing Record 1 of Set 7 | ust-barguzin
# Processing Record 2 of Set 7 | marzuq
# Processing Record 3 of Set 7 | nemuro
# Processing Record 4 of Set 7 | bathsheba
# Processing Record 5 of Set 7 | wukari
# Processing Record 6 of Set 7 | mosquera
# Processing Record 7 of Set 7 | ramsar
# Processing Record 8 of Set 7 | yelan
# Processing Record 9 of Set 7 | saint-pierre
# Processing Record 10 of Set 7 | turukhansk
# Processing Record 11 of Set 7 | kayerkan
# Processing Record 12 of Set 7 | mamlyutka
# Processing Record 13 of Set 7 | sam chuk
# Processing Record 14 of Set 7 | prince george
# Processing Record 15 of Set 7 | sao joao da barra
# City not found. Skipping...
# Processing Record 16 of Set 7 | tual
# Processing Record 17 of Set 7 | bilibino
# Processing Record 18 of Set 7 | hamilton
# Processing Record 19 of Set 7 | mikhaylovka
# City not found. Skipping...
# Processing Record 20 of Set 7 | saint-augustin
# Processing Record 21 of Set 7 | comoapan
# Processing Record 22 of Set 7 | biak
# Processing Record 23 of Set 7 | carauari
# Processing Record 24 of Set 7 | kropotkin
# Processing Record 25 of Set 7 | simbahan
# Processing Record 26 of Set 7 | srednekolymsk
# Processing Record 27 of Set 7 | springdale
# Processing Record 28 of Set 7 | sola
# Processing Record 29 of Set 7 | toropets
# Processing Record 30 of Set 7 | pallasovka
# Processing Record 31 of Set 7 | port harcourt
# Processing Record 32 of Set 7 | kutum
# Processing Record 33 of Set 7 | dickinson
# Processing Record 34 of Set 7 | port-cartier
# Processing Record 35 of Set 7 | vardo
# Processing Record 36 of Set 7 | oistins
# Processing Record 37 of Set 7 | hovd
# Processing Record 38 of Set 7 | pisco
# Processing Record 7 of Set 9 | goderich
# Processing Record 8 of Set 9 | mingaora
# Processing Record 9 of Set 9 | brae
# Processing Record 10 of Set 9 | muisne
# Processing Record 11 of Set 9 | miri
# Processing Record 12 of Set 9 | cururupu
# Processing Record 13 of Set 9 | marsa matruh
# Processing Record 14 of Set 9 | port lincoln
# Processing Record 15 of Set 9 | lavrentiya
# Processing Record 16 of Set 9 | poso
# City not found. Skipping...
# Processing Record 17 of Set 9 | pali
# Processing Record 18 of Set 9 | braine-le-comte
# Processing Record 19 of Set 9 | jining
# Processing Record 20 of Set 9 | ekhabi
# Processing Record 21 of Set 9 | mtambile
# City not found. Skipping...
# Processing Record 22 of Set 9 | bonavista
# Processing Record 23 of Set 9 | qianan
# Processing Record 24 of Set 9 | selenginsk
# Processing Record 25 of Set 9 | goundam
# City not found. Skipping...
# Processing Record 26 of Set 9 | mangaluru
# Processing Record 27 of Set 9 | port-gentil
# Processing Record 28 of Set 9 | gawler
# Processing Record 29 of Set 9 | havre-saint-pierre
# Processing Record 30 of Set 9 | roma
# Processing Record 31 of Set 9 | khromtau
# Processing Record 32 of Set 9 | alvand
# Processing Record 33 of Set 9 | constitucion
# Processing Record 34 of Set 9 | korla
# Processing Record 35 of Set 9 | koregaon
# Processing Record 36 of Set 9 | sorong
# Processing Record 37 of Set 9 | gat
# Processing Record 38 of Set 9 | yashkul
# City not found. Skipping...
# Processing Record 39 of Set 9 | fandriana
# City not found. Skipping...
# Processing Record 40 of Set 9 | terrace
# Processing Record 41 of Set 9 | manaure
# Processing Record 42 of Set 9 | rebrikha
# Processing Record 43 of Set 9 | krasnoselkup
# Processing Record 44 of Set 9 | henties bay
# Processing Record 45 of Set 9 | vao
# Processing Record 46 of Set 9 | belgrade
# City not found. Skipping...
# Processing Record 47 of Set 9 | khandyga
# Processing Record 48 of Set 9 | cumana
# Processing Record 49 of Set 9 | big spring
# Processing Record 50 of Set 9 | ondjiva
# Processing Record 0 of Set 10 | cachoeira do sul
# Processing Record 1 of Set 10 | vargem grande
# Processing Record 2 of Set 10 | salavat
# Processing Record 3 of Set 10 | sioux lookout
# Processing Record 4 of Set 10 | grindavik
# Processing Record 5 of Set 10 | kabalo
# Processing Record 6 of Set 10 | tezu
# Processing Record 7 of Set 10 | zilair
# Processing Record 8 of Set 10 | puerto madryn
# Processing Record 9 of Set 10 | kabo
# Processing Record 10 of Set 10 | bitung
# Processing Record 11 of Set 10 | baikunthpur
# Processing Record 12 of Set 10 | mugur-aksy
# Processing Record 13 of Set 10 | san bartolome de tirajana
# Processing Record 14 of Set 10 | paamiut
# Processing Record 15 of Set 10 | mlonggo
# Processing Record 16 of Set 10 | muravlenko
# Processing Record 17 of Set 10 | tateyama
# Processing Record 18 of Set 10 | kalmunai
# Processing Record 19 of Set 10 | bayangol
# Processing Record 20 of Set 10 | yar-sale
# Processing Record 21 of Set 10 | shieli
# Processing Record 22 of Set 10 | da lat
# Processing Record 23 of Set 10 | bettiah
# Processing Record 24 of Set 10 | salinas
# Processing Record 25 of Set 10 | verkhnevilyuysk
# Processing Record 26 of Set 10 | altamont
# Processing Record 27 of Set 10 | tosya
# City not found. Skipping...
# Processing Record 28 of Set 10 | svetlogorsk
# Processing Record 29 of Set 10 | zhovti vody
# Processing Record 30 of Set 10 | monster
# Processing Record 31 of Set 10 | alihe
# Processing Record 32 of Set 10 | malartic
# Processing Record 33 of Set 10 | uarini
# City not found. Skipping...
# Processing Record 34 of Set 10 | hami
# Processing Record 35 of Set 10 | kollegal
# Processing Record 36 of Set 10 | esna
# Processing Record 37 of Set 10 | williston
# Processing Record 38 of Set 10 | athabasca
# Processing Record 39 of Set 10 | beringovskiy
# Processing Record 40 of Set 10 | antofagasta
# Processing Record 41 of Set 10 | ocos
# Processing Record 42 of Set 10 | bungu
# Processing Record 43 of Set 10 | doka
# City not found. Skipping...
# Processing Record 44 of Set 10 | palembang
# Processing Record 45 of Set 10 | coihaique
# Processing Record 46 of Set 10 | yarada
# Processing Record 47 of Set 10 | voi
# Processing Record 48 of Set 10 | tyshkivka
# Processing Record 49 of Set 10 | tres arroyos
# Processing Record 50 of Set 10 | porto novo
# Processing Record 0 of Set 11 | sao jose da coroa grande
# Processing Record 1 of Set 11 | aksu
# Processing Record 2 of Set 11 | asyut
# Processing Record 3 of Set 11 | sobolevo
# Processing Record 4 of Set 11 | tiarei
# Processing Record 5 of Set 11 | calama
# Processing Record 6 of Set 11 | pimenta bueno
# Processing Record 7 of Set 11 | konstantinovka
# Processing Record 8 of Set 11 | inirida
# Processing Record 9 of Set 11 | kaarina
# City not found. Skipping...
# Processing Record 10 of Set 11 | zverinogolovskoye
# Processing Record 11 of Set 11 | manokwari
# Processing Record 12 of Set 11 | mogadouro
# Processing Record 13 of Set 11 | meadow lake
# Processing Record 14 of Set 11 | srandakan
# Processing Record 15 of Set 11 | sept-iles
# Processing Record 16 of Set 11 | sagua de tanamo
# City not found. Skipping...
# Processing Record 17 of Set 11 | hojo
# City not found. Skipping...
# Processing Record 18 of Set 11 | bulaevo
# Processing Record 19 of Set 11 | sisimiut
# City not found. Skipping...
# Processing Record 20 of Set 11 | ormara
# Processing Record 21 of Set 11 | collie
# Processing Record 22 of Set 11 | chicama
# Processing Record 23 of Set 11 | sao lourenco do sul
# Processing Record 24 of Set 11 | preobrazheniye
# Processing Record 25 of Set 11 | lastoursville
# City not found. Skipping...
# Processing Record 26 of Set 11 | anito
# Processing Record 27 of Set 11 | vilhena
# Processing Record 28 of Set 11 | muzhi
# Processing Record 29 of Set 11 | lorengau
# Processing Record 30 of Set 11 | asau
# Processing Record 31 of Set 11 | nenjiang
# Processing Record 32 of Set 11 | miramar
# Processing Record 33 of Set 11 | vagur
# Processing Record 34 of Set 11 | inongo
# Processing Record 35 of Set 11 | camana
# City not found. Skipping...
# Processing Record 36 of Set 11 | wau
# City not found. Skipping...
# Processing Record 37 of Set 11 | hun
# Processing Record 38 of Set 11 | shibetsu
# Processing Record 39 of Set 11 | mgachi
# Processing Record 40 of Set 11 | chumikan
# Processing Record 41 of Set 11 | varhaug
# Processing Record 42 of Set 11 | zhigalovo
# Processing Record 43 of Set 11 | kupang
# Processing Record 44 of Set 11 | forest grove
# Processing Record 45 of Set 11 | pauini
# Processing Record 46 of Set 11 | san pedro
# Processing Record 47 of Set 11 | kirakira
# Processing Record 48 of Set 11 | mayo
# Processing Record 49 of Set 11 | yelets
# Processing Record 50 of Set 11 | launceston
# Processing Record 0 of Set 12 | padilla
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Creating panda dataframe 

cityWeather_df = pd.DataFrame({"City" :cityList,
                            "Latitude" : latList,
                            "Longitude" : lngList,
                            "Max Temperature" : maxTempList,
                            "Humidity" : humidityList,
                            "Cloudiness" : cloudinessList,
                            "Wind Speed" : windSpeedList,
                            "Country" : countryList,
                            "Date" : dateList
})

# Export to CSV 
cityWeather_df.to_csv("cityWeatherOutput.csv", index = False)

# Display to dataframe 
cityWeather_df.head()
# Out:
#               City  Latitude  Longitude  Max Temperature  Humidity  \
# 0  Arraial do Cabo  -22.9661   -42.0278            80.56        57
# 1          Rikitea  -23.1203  -134.9692            69.30        62
# 2         Tasiilaq   65.6145   -37.6368            42.96        85
# 3    Half Moon Bay   37.4636  -122.4286            59.79        88
# 4    Montefiascone   42.5393    12.0362            86.45        61
#
#    Cloudiness  Wind Speed Country        Date
# 0           0       11.50      BR  1629725590
# 1          28       19.64      PF  1629725501
# 2          41        2.62      GL  1629725589
# 3          90        1.99      US  1629725711
# 4          75        8.99      IT  1629725711

# %%
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  599.000000  599.000000  599.000000  599.000000  599.000000  599.000000
# mean    19.877028   19.568998   69.794808   69.353923   51.569282    7.979416
# std     33.262944   91.418472   15.678452   22.704698   35.405602    5.660694
# min    -54.800000 -179.170000   12.200000    7.000000    0.000000    0.360000
# 25%     -8.540000  -61.210000   59.000000   55.000000   20.000000    3.620000
# 50%     24.370000   24.670000   73.110000   75.000000   59.000000    6.730000
# 75%     46.585000  102.255000   80.600000   87.000000   85.000000   11.050000
# max     78.220000  179.320000  116.600000  100.000000  100.000000   42.500000
#
#                Date
# count  5.990000e+02
# mean   1.593605e+09
# std    5.738815e+01
# min    1.593605e+09
# 25%    1.593605e+09
# 50%    1.593605e+09
# 75%    1.593605e+09
# max    1.593605e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  550.000000  550.000000  550.000000  550.000000  550.000000  550.000000
# mean    19.973545   17.124400   58.331400   67.890909   52.141818    8.544800
# std     33.284840   91.595451   25.795297   20.864881   35.766469    6.078869
# min    -54.800000 -179.170000  -11.340000    9.000000    0.000000    0.160000
# 25%     -8.077500  -64.627500   42.800000   55.000000   20.000000    4.525000
# 50%     23.630000   19.635000   64.940000   72.000000   57.000000    7.325000
# 75%     48.672500   97.350000   78.800000   83.000000   86.750000   11.410000
# max     78.220000  179.320000  102.200000  100.000000  100.000000   46.080000
#
#                Date
# count  5.500000e+02
# mean   1.585764e+09
# std    5.539674e+01
# min    1.585764e+09
# 25%    1.585764e+09
# 50%    1.585764e+09
# 75%    1.585764e+09
# max    1.585764e+09

# %%
#  Get the indices of cities that have humidity over 100%.
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   butaritari   3.07  172.79     83.32        74          84       10.42
# 1  yerbogachen  61.28  108.01     79.52        58          20        7.70
# 2    cape town -33.93   18.42     73.00        77          27        4.70
# 3        touba   8.28   -7.68     79.97        75          82        3.58
# 4    jamestown  42.10  -79.24     64.00        88           1        6.93
#
#   Country        Date
# 0      KI  1593605283
# 1      RU  1593605121
# 2      ZA  1593605039
# 3      CI  1593605284
# 4      US  1593605284

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Lat vs Temperature scatter Plot 

plt.scatter(cityWeather_df["Latitude"], cityWeather_df['Max Temperature'], facecolor = 'steelblue', edgecolor = 'black')

# Title 
plt.title('City Latitude vs. Max Temperature (04/01/20)')

# X-axis Lable
plt.xlabel('Latitude')

# Y-axis Lable
plt.ylabel('Max Temperature (F)')

# Grid Lines
plt.grid (linestyle = '-', linewidth = 1, alpha = .5)

# Save as png
plt.savefig("Images/LatitudevsTemp.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Lat vs Temperature scatter Plot 

plt.scatter(cityWeather_df["Latitude"], cityWeather_df['Humidity'], facecolor = 'steelblue', edgecolor = 'black')

# Title 
plt.title('City Latitude vs. Humidity (04/01/20)')

# X-axis Lable
plt.xlabel('Latitude')

# Y-axis Lable
plt.ylabel('Humidity (%)')

# Grid Lines
plt.grid (linestyle = '-', linewidth = 1, alpha = .5)

# Save as png
plt.savefig("Images/LatitudevsHumidity.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Lat vs Temperature scatter Plot 

plt.scatter(cityWeather_df["Latitude"], cityWeather_df['Cloudiness'], facecolor = 'steelblue', edgecolor = 'black')

# Title 
plt.title('City Latitude vs. Cloudiness (04/01/20)')

# X-axis Lable
plt.xlabel('Latitude')

# Y-axis Lable
plt.ylabel('Cloudiness (%)')

# Grid Lines
plt.grid (linestyle = '-', linewidth = 1, alpha = .5)

# Save as png
plt.savefig("Images/LatitudevsCloudiness.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Lat vs Temperature scatter Plot 

plt.scatter(cityWeather_df["Latitude"], cityWeather_df['Wind Speed'], facecolor = 'steelblue', edgecolor = 'black')

# Title 
plt.title('City Latitude vs. Wind Speed (04/01/20)')

# X-axis Lable
plt.xlabel('Latitude')

# Y-axis Lable
plt.ylabel('Wind Speed (mph)')

# Grid Lines
plt.grid (linestyle = '-', linewidth = 1, alpha = .5)

# Save as png
plt.savefig("Images/LatitudevsWindSpeed.png")

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames

northernHemisphere = cityWeather_df.loc[cityWeather_df["Latitude"] >= 0]
southernHemisphere = cityWeather_df.loc[cityWeather_df["Latitude"] < 0]

# %%
southernHemisphere[["Max Temperature"]]
# Out:
#      Max Temperature
# 0              80.56
# 1              69.30
# 6              35.26
# 13             70.09
# 14             68.16
# ..               ...
# 544            61.86
# 552            76.19
# 554            93.60
# 556            78.03
# 559            41.81
#
# [165 rows x 1 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x1 = northernHemisphere["Latitude"]
y1 = northernHemisphere["Max Temperature"]
# Calculate correlation coefficient 
corCof = st.pearsonr(x1, y1)
print(f" The r-value is: {round(st.pearsonr(x1,y1)[0],2)}")

# Calculate linear regression line 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x1, y1)
regressValues = x * slope + intercept
lineEquation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# plot scatter and linear regression 
plt.scatter(x1, y1)
plt.plot(x1, regressValues, 'r-')

# Label of lincear regression 
plt.annotate(lineEquation,(0,50), fontsize= 15, color = 'Red')

# Label graph
plt.xlabel('Latitude)')
plt.ylabel('Max Temp')
plt.title('Max Temp vs Latitude (Nothern Hemisphere)')
plt.show()
# Out:
#  The r-value is: -0.7

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x1 = southernHemisphere["Latitude"]
y1 = southernHemisphere["Max Temperature"]


# Calculate correlation coefficient 
corCof = st.pearsonr(x1, y1)
print(f" The r-value is: {round(st.pearsonr(x1,y1)[0],4)}")

# Calculate linear regression line 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x1, y1)
regressValues = x * slope + intercept
lineEquation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# plot scatter and linear regression 
plt.scatter(x1, y1)
plt.plot(x1, regressValues, 'r-')

# Label of lincear regression 
plt.annotate(lineEquation,(-30,50), fontsize= 15, color = 'Red')
       
# Label graph
plt.xlabel('Latitude)')
plt.ylabel('Max Temp')
plt.title('Max Temp vs Latitude (Southern Hemisphere)')
plt.show()
# Out:
#  The r-value is: 0.7814
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-64e5780065df> in <module>
#      14 # plot scatter and linear regression
#      15 plt.scatter(x1, y1)
# ---> 16 plt.plot(x1, regressValues, 'r-')
#      17
#      18 # Label of lincear regression
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#    2842         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     271                 this += args[0],
#     272                 args = args[1:]
# --> 273             yield from self._plot_args(this, kwargs)
#     274
#     275     def get_next_color(self):
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     397
#     398         if x.shape[0] != y.shape[0]:
# --> 399             raise ValueError(f"x and y must have same first dimension, but "
#     400                              f"have shapes {x.shape} and {y.shape}")
#     401         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (165,) and (396,)

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x1 = northernHemisphere["Latitude"]
y1 = northernHemisphere["Humidity"]

# Calculate correlation coefficient 
corCof = st.pearsonr(x1, y1)
print(f" The r-value is: {round(st.pearsonr(x1,y1)[0],4)}")

# Calculate linear regression line 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x1, y1)
regressValues = x * slope + intercept
lineEquation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# plot scatter and linear regression 
plt.scatter(x1, y1)
plt.plot(x1, regressValues, 'r-')

# Label of lincear regression 
plt.annotate(lineEquation,(30,50), fontsize= 15, color = 'Red')

# Label graph
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Latitude vs Humidity (Nothern Hemisphere)')
plt.show()
# Out:
#  The r-value is: 0.0589

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x1 = southernHemisphere["Latitude"]
y1 = southernHemisphere["Humidity"]

# Calculate correlation coefficient 
corCof = st.pearsonr(x1, y1)
print(f" The r-value is: {round(st.pearsonr(x1,y1)[0],2)}")

# Calculate linear regression line 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x1, y1)
regressValues = x * slope + intercept
lineEquation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# plot scatter and linear regression 
plt.scatter(x1, y1)
plt.plot(x1, regressValues, 'r-')

# Label of lincear regression 
plt.annotate(lineEquation,(-30,50), fontsize= 15, color = 'Red')

# Label graph
plt.xlabel('Latitude)')
plt.ylabel('Humidity')
plt.title('Latitude vs Humidity (Southern Hemisphere)')
plt.show()
# Out:
#  The r-value is: -0.03
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-6a2e8f3efd62> in <module>
#      13 # plot scatter and linear regression
#      14 plt.scatter(x1, y1)
# ---> 15 plt.plot(x1, regressValues, 'r-')
#      16
#      17 # Label of lincear regression
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#    2842         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     271                 this += args[0],
#     272                 args = args[1:]
# --> 273             yield from self._plot_args(this, kwargs)
#     274
#     275     def get_next_color(self):
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     397
#     398         if x.shape[0] != y.shape[0]:
# --> 399             raise ValueError(f"x and y must have same first dimension, but "
#     400                              f"have shapes {x.shape} and {y.shape}")
#     401         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (165,) and (396,)

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x1 = northernHemisphere["Latitude"]
y1 = northernHemisphere["Cloudiness"]

# Calculate correlation coefficient 
corCof = st.pearsonr(x1, y1)
print(f" The r-value is: {round(st.pearsonr(x1,y1)[0],4)}")

# Calculate linear regression line 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x1, y1)
regressValues = x * slope + intercept
lineEquation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# plot scatter and linear regression 
plt.scatter(x1, y1)
plt.plot(x1, regressValues, 'r-')

# Label of lincear regression 
plt.annotate(lineEquation,(20,50), fontsize= 15, color = 'Red')

# Label graph
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
plt.title('Latitude vs Cloudiness (Nothern Hemisphere)')
plt.show()
# Out:
#  The r-value is: 0.0235

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x1 = northernHemisphere["Latitude"]
y1 = northernHemisphere["Wind Speed"]

# Calculate correlation coefficient 
corCof = st.pearsonr(x1, y1)
print(f" The r-value is: {round(st.pearsonr(x1,y1)[0],4)}")

# Calculate linear regression line 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x1, y1)
regressValues = x * slope + intercept
lineEquation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# plot scatter and linear regression 
plt.scatter(x1, y1)
plt.plot(x1, regressValues, 'r-')

# Label of lincear regression 
plt.annotate(lineEquation,(30,20), fontsize= 15, color = 'Red')

# Label graph
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Latitude vs Wind Speed (Nothern Hemisphere)')
plt.show()
# Out:
#  The r-value is: -0.0293

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
